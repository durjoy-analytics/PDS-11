# %% [markdown]
# Project 2: Dataset Merging, Data Manipulation, K-Means Clustering
# 1. Create a CSV file with the name, ‘term-test-1-result.csv’.
# There’ll be three columns: ‘Registration Number’, ‘Name’, and ‘TT-1 Marks’.
# You must include 50 students with their respective values for each column in the file.
# 2. Follow step 1 and create another CSV file with the name, ‘term-test-2-result.csv’.
# ‘Registration Number’, ‘Name’ columns will have the same values as mentioned in the
# ‘term-test-1-result.csv’ file. The value of the ‘TT-2 Marks’ column is most likely to be changed.
# Note: Don’t make both files identical, and you mustn't copy each other’s files.
# 3. Load both the files in different pandas dataframes.
# Make a new merged pandas dataframe on their ‘Registration Number’ column.
# 4. Make a new column with the best term test marks for each student.
# Make a new column with the average term test marks for each student.
# 5. Drop both the columns named ‘TT-1 Marks’ and ‘TT-2 Marks’.
# 6. Write the content of the latest pandas dataframe to a new CSV file named ‘final term test result.csv’.
# 7. Cluster the average marks of each student using K-Means clustering algorithm. (1<K<6)
# Visualize the final clusters

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv("C:\\Downloads\\term-test-1-result.csv")


df2 = pd.read_csv("C:\\Downloads\\term-test-2-result.csv")

# %%
df1.head()
# Out:
#   Registration Number       Name  TT-1 Marks
# 0         REG2025-001  Student 1          60
# 1         REG2025-002  Student 2          69
# 2         REG2025-003  Student 3          35
# 3         REG2025-004  Student 4          41
# 4         REG2025-005  Student 5          63

# %%
df2.head()
# Out:
#   Registration Number       Name  TT-2 Marks
# 0         REG2025-001  Student 1          74
# 1         REG2025-002  Student 2          58
# 2         REG2025-003  Student 3          37
# 3         REG2025-004  Student 4          36
# 4         REG2025-005  Student 5          65

# %%
df_merged = pd.merge(df1, df2, on="Registration Number")

# Display the first few rows of the merged DataFrame
print(df_merged)
# Out:
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks
# 0          REG2025-001   Student 1          60   Student 1          74
# 1          REG2025-002   Student 2          69   Student 2          58
# 2          REG2025-003   Student 3          35   Student 3          37
# 3          REG2025-004   Student 4          41   Student 4          36
# 4          REG2025-005   Student 5          63   Student 5          65
# 5          REG2025-006   Student 6          49   Student 6          86
# 6          REG2025-007   Student 7          92   Student 7          48
# 7          REG2025-008   Student 8          32   Student 8          37
# 8          REG2025-009   Student 9          89   Student 9          75
# 9          REG2025-010  Student 10          37  Student 10          50
# 10         REG2025-011  Student 11          90  Student 11          35
# 11         REG2025-012  Student 12          85  Student 12          61
# 12         REG2025-013  Student 13          36  Student 13          89
# 13         REG2025-014  Student 14          99  Student 14          60
# 14         REG2025-015  Student 15          49  Student 15          51
# 15         REG2025-016  Student 16          77  Student 16          85
# 16         REG2025-017  Student 17          83  Student 17          97
# 17         REG2025-018  Student 18          39  Student 18          82
# 18         REG2025-019  Student 19          53  Student 19          67
# 19         REG2025-020  Student 20          33  Student 20          34
# 20         REG2025-021  Student 21          41  Student 21          51
# 21         REG2025-022  Student 22          54  Student 22          66
# 22         REG2025-023  Student 23          51  Student 23          68
# 23         REG2025-024  Student 24          39  Student 24          77
# 24         REG2025-025  Student 25          50  Student 25          76
# 25         REG2025-026  Student 26          56  Student 26          82
# 26         REG2025-027  Student 27          73  Student 27          32
# 27         REG2025-028  Student 28          86  Student 28          86
# 28         REG2025-029  Student 29          63  Student 29          90
# 29         REG2025-030  Student 30          39  Student 30          66
# 30         REG2025-031  Student 31          97  Student 31          57
# 31         REG2025-032  Student 32          67  Student 32          47
# 32         REG2025-033  Student 33          66  Student 33          56
# 33         REG2025-034  Student 34          60  Student 34          41
# 34         REG2025-035  Student 35          64  Student 35          99
# 35         REG2025-036  Student 36          31  Student 36          75
# 36         REG2025-037  Student 37          69  Student 37          56
# 37         REG2025-038  Student 38          39  Student 38          76
# 38         REG2025-039  Student 39          74  Student 39          93
# 39         REG2025-040  Student 40          71  Student 40          95
# 40         REG2025-041  Student 41          51  Student 41          55
# 41         REG2025-042  Student 42          48  Student 42          94
# 42         REG2025-043  Student 43         100  Student 43          40
# 43         REG2025-044  Student 44          93  Student 44          92
# 44         REG2025-045  Student 45          36  Student 45          75
# 45         REG2025-046  Student 46          92  Student 46          99
# 46         REG2025-047  Student 47          71  Student 47          89
# 47         REG2025-048  Student 48          91  Student 48         100
# 48         REG2025-049  Student 49          99  Student 49          35
# 49         REG2025-050  Student 50          37  Student 50          69

# %%
df_merged["Best Marks"] = df_merged[["TT-1 Marks", "TT-2 Marks"]].max(axis=1)


print(df_merged.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks     Name_y  TT-2 Marks  \
# 0         REG2025-001  Student 1          60  Student 1          74
# 1         REG2025-002  Student 2          69  Student 2          58
# 2         REG2025-003  Student 3          35  Student 3          37
# 3         REG2025-004  Student 4          41  Student 4          36
# 4         REG2025-005  Student 5          63  Student 5          65
#
#    Best Marks
# 0          74
# 1          69
# 2          37
# 3          41
# 4          65

# %%
df_merged
# Out:
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks  \
# 0          REG2025-001   Student 1          60   Student 1          74
# 1          REG2025-002   Student 2          69   Student 2          58
# 2          REG2025-003   Student 3          35   Student 3          37
# 3          REG2025-004   Student 4          41   Student 4          36
# 4          REG2025-005   Student 5          63   Student 5          65
# 5          REG2025-006   Student 6          49   Student 6          86
# 6          REG2025-007   Student 7          92   Student 7          48
# 7          REG2025-008   Student 8          32   Student 8          37
# 8          REG2025-009   Student 9          89   Student 9          75
# 9          REG2025-010  Student 10          37  Student 10          50
# 10         REG2025-011  Student 11          90  Student 11          35
# 11         REG2025-012  Student 12          85  Student 12          61
# 12         REG2025-013  Student 13          36  Student 13          89
# 13         REG2025-014  Student 14          99  Student 14          60
# 14         REG2025-015  Student 15          49  Student 15          51
# 15         REG2025-016  Student 16          77  Student 16          85
# 16         REG2025-017  Student 17          83  Student 17          97
# 17         REG2025-018  Student 18          39  Student 18          82
# 18         REG2025-019  Student 19          53  Student 19          67
# 19         REG2025-020  Student 20          33  Student 20          34
# 20         REG2025-021  Student 21          41  Student 21          51
# 21         REG2025-022  Student 22          54  Student 22          66
# 22         REG2025-023  Student 23          51  Student 23          68
# 23         REG2025-024  Student 24          39  Student 24          77
# 24         REG2025-025  Student 25          50  Student 25          76
# 25         REG2025-026  Student 26          56  Student 26          82
# 26         REG2025-027  Student 27          73  Student 27          32
# 27         REG2025-028  Student 28          86  Student 28          86
# 28         REG2025-029  Student 29          63  Student 29          90
# 29         REG2025-030  Student 30          39  Student 30          66
# 30         REG2025-031  Student 31          97  Student 31          57
# 31         REG2025-032  Student 32          67  Student 32          47
# 32         REG2025-033  Student 33          66  Student 33          56
# 33         REG2025-034  Student 34          60  Student 34          41
# 34         REG2025-035  Student 35          64  Student 35          99
# 35         REG2025-036  Student 36          31  Student 36          75
# 36         REG2025-037  Student 37          69  Student 37          56
# 37         REG2025-038  Student 38          39  Student 38          76
# 38         REG2025-039  Student 39          74  Student 39          93
# 39         REG2025-040  Student 40          71  Student 40          95
# 40         REG2025-041  Student 41          51  Student 41          55
# 41         REG2025-042  Student 42          48  Student 42          94
# 42         REG2025-043  Student 43         100  Student 43          40
# 43         REG2025-044  Student 44          93  Student 44          92
# 44         REG2025-045  Student 45          36  Student 45          75
# 45         REG2025-046  Student 46          92  Student 46          99
# 46         REG2025-047  Student 47          71  Student 47          89
# 47         REG2025-048  Student 48          91  Student 48         100
# 48         REG2025-049  Student 49          99  Student 49          35
# 49         REG2025-050  Student 50          37  Student 50          69
#
#     Best Marks
# 0           74
# 1           69
# 2           37
# 3           41
# 4           65
# 5           86
# 6           92
# 7           37
# 8           89
# 9           50
# 10          90
# 11          85
# 12          89
# 13          99
# 14          51
# 15          85
# 16          97
# 17          82
# 18          67
# 19          34
# 20          51
# 21          66
# 22          68
# 23          77
# 24          76
# 25          82
# 26          73
# 27          86
# 28          90
# 29          66
# 30          97
# 31          67
# 32          66
# 33          60
# 34          99
# 35          75
# 36          69
# 37          76
# 38          93
# 39          95
# 40          55
# 41          94
# 42         100
# 43          93
# 44          75
# 45          99
# 46          89
# 47         100
# 48          99
# 49          69

# %%
# Create a new column with the average marks from TT-1 and TT-2
df_merged["Average Marks"] = df_merged[["TT-1 Marks", "TT-2 Marks"]].mean(axis=1)

# Display the updated DataFrame
print(df_merged.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks     Name_y  TT-2 Marks  \
# 0         REG2025-001  Student 1          60  Student 1          74
# 1         REG2025-002  Student 2          69  Student 2          58
# 2         REG2025-003  Student 3          35  Student 3          37
# 3         REG2025-004  Student 4          41  Student 4          36
# 4         REG2025-005  Student 5          63  Student 5          65
#
#    Best Marks  Average Marks
# 0          74           67.0
# 1          69           63.5
# 2          37           36.0
# 3          41           38.5
# 4          65           64.0

# %%
df_merged
# Out:
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks  \
# 0          REG2025-001   Student 1          60   Student 1          74
# 1          REG2025-002   Student 2          69   Student 2          58
# 2          REG2025-003   Student 3          35   Student 3          37
# 3          REG2025-004   Student 4          41   Student 4          36
# 4          REG2025-005   Student 5          63   Student 5          65
# 5          REG2025-006   Student 6          49   Student 6          86
# 6          REG2025-007   Student 7          92   Student 7          48
# 7          REG2025-008   Student 8          32   Student 8          37
# 8          REG2025-009   Student 9          89   Student 9          75
# 9          REG2025-010  Student 10          37  Student 10          50
# 10         REG2025-011  Student 11          90  Student 11          35
# 11         REG2025-012  Student 12          85  Student 12          61
# 12         REG2025-013  Student 13          36  Student 13          89
# 13         REG2025-014  Student 14          99  Student 14          60
# 14         REG2025-015  Student 15          49  Student 15          51
# 15         REG2025-016  Student 16          77  Student 16          85
# 16         REG2025-017  Student 17          83  Student 17          97
# 17         REG2025-018  Student 18          39  Student 18          82
# 18         REG2025-019  Student 19          53  Student 19          67
# 19         REG2025-020  Student 20          33  Student 20          34
# 20         REG2025-021  Student 21          41  Student 21          51
# 21         REG2025-022  Student 22          54  Student 22          66
# 22         REG2025-023  Student 23          51  Student 23          68
# 23         REG2025-024  Student 24          39  Student 24          77
# 24         REG2025-025  Student 25          50  Student 25          76
# 25         REG2025-026  Student 26          56  Student 26          82
# 26         REG2025-027  Student 27          73  Student 27          32
# 27         REG2025-028  Student 28          86  Student 28          86
# 28         REG2025-029  Student 29          63  Student 29          90
# 29         REG2025-030  Student 30          39  Student 30          66
# 30         REG2025-031  Student 31          97  Student 31          57
# 31         REG2025-032  Student 32          67  Student 32          47
# 32         REG2025-033  Student 33          66  Student 33          56
# 33         REG2025-034  Student 34          60  Student 34          41
# 34         REG2025-035  Student 35          64  Student 35          99
# 35         REG2025-036  Student 36          31  Student 36          75
# 36         REG2025-037  Student 37          69  Student 37          56
# 37         REG2025-038  Student 38          39  Student 38          76
# 38         REG2025-039  Student 39          74  Student 39          93
# 39         REG2025-040  Student 40          71  Student 40          95
# 40         REG2025-041  Student 41          51  Student 41          55
# 41         REG2025-042  Student 42          48  Student 42          94
# 42         REG2025-043  Student 43         100  Student 43          40
# 43         REG2025-044  Student 44          93  Student 44          92
# 44         REG2025-045  Student 45          36  Student 45          75
# 45         REG2025-046  Student 46          92  Student 46          99
# 46         REG2025-047  Student 47          71  Student 47          89
# 47         REG2025-048  Student 48          91  Student 48         100
# 48         REG2025-049  Student 49          99  Student 49          35
# 49         REG2025-050  Student 50          37  Student 50          69
#
#     Best Marks  Average Marks
# 0           74           67.0
# 1           69           63.5
# 2           37           36.0
# 3           41           38.5
# 4           65           64.0
# 5           86           67.5
# 6           92           70.0
# 7           37           34.5
# 8           89           82.0
# 9           50           43.5
# 10          90           62.5
# 11          85           73.0
# 12          89           62.5
# 13          99           79.5
# 14          51           50.0
# 15          85           81.0
# 16          97           90.0
# 17          82           60.5
# 18          67           60.0
# 19          34           33.5
# 20          51           46.0
# 21          66           60.0
# 22          68           59.5
# 23          77           58.0
# 24          76           63.0
# 25          82           69.0
# 26          73           52.5
# 27          86           86.0
# 28          90           76.5
# 29          66           52.5
# 30          97           77.0
# 31          67           57.0
# 32          66           61.0
# 33          60           50.5
# 34          99           81.5
# 35          75           53.0
# 36          69           62.5
# 37          76           57.5
# 38          93           83.5
# 39          95           83.0
# 40          55           53.0
# 41          94           71.0
# 42         100           70.0
# 43          93           92.5
# 44          75           55.5
# 45          99           95.5
# 46          89           80.0
# 47         100           95.5
# 48          99           67.0
# 49          69           53.0

# %%
df_merged = df_merged.drop(columns=["TT-1 Marks", "TT-2 Marks"])


df_merged.head()
# Out:
#   Registration Number     Name_x     Name_y  Best Marks  Average Marks
# 0         REG2025-001  Student 1  Student 1          74           67.0
# 1         REG2025-002  Student 2  Student 2          69           63.5
# 2         REG2025-003  Student 3  Student 3          37           36.0
# 3         REG2025-004  Student 4  Student 4          41           38.5
# 4         REG2025-005  Student 5  Student 5          65           64.0

# %%
# Save the updated DataFrame to a new CSV file
df_merged.to_csv("final term test result.csv", index=False)

print("Final term test result saved successfully!")
# Out:
# Final term test result saved successfully!

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


# Extract the 'Average Marks' column for clustering
X = df_merged[["Average Marks"]]

# Apply K-Means clustering with a chosen value of K (e.g., K=3)
kmeans = KMeans(n_clusters=3, random_state=42)
df_merged["Cluster"] = kmeans.fit_predict(X)

# Plot the clusters
plt.figure(figsize=(10, 6))
plt.scatter(df_merged["Average Marks"], [1]*len(df_merged), c=df_merged["Cluster"], cmap='viridis', marker='o')
plt.title("K-Means Clustering of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Cluster")
plt.yticks([])  # Hide the y-axis ticks
plt.colorbar(label='Cluster')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
